# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## 2a
# ### 120x120
# - 233MB
# - 490s
#
# ### 80x80
# - 229MB
# - 490s

# %%
df1 = pd.read_csv('2a_out.csv')
df2 = pd.read_csv('2a_secant_out.csv').dropna()

# %%
# load PFHub results
with open('results.2a.1.json') as f:
  j1 = json.load(f)
j2 = json.loads('[{"hovertemplate":"Simulation Result=moose_2a_guan<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_2a_guan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"moose_2a_guan","orientation":"h","showlegend":true,"x":[0.03186],"xaxis":"x","y":["3664185.48"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=fenics_2a_ivan<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"fenics_2a_ivan","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"fenics_2a_ivan","orientation":"h","showlegend":true,"x":[0.029505253891033298],"xaxis":"x","y":["6795288"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_2a_xueyang94<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_2a_xueyang94","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"moose_2a_xueyang94","orientation":"h","showlegend":true,"x":[0.004145171957671958],"xaxis":"x","y":["12531700"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_itg_2a<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_itg_2a","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"moose_itg_2a","orientation":"h","showlegend":true,"x":[0.16416],"xaxis":"x","y":["37927391"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_fh_2a<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_fh_2a","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"moose_fh_2a","orientation":"h","showlegend":true,"x":[0.07086],"xaxis":"x","y":["1643671"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_2a_sta<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_2a_sta","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"moose_2a_sta","orientation":"h","showlegend":true,"x":[0.5573161417965804],"xaxis":"x","y":[3145728.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_2a_ia<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_2a_ia","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"moose_2a_ia","orientation":"h","showlegend":true,"x":[0.966161055330013],"xaxis":"x","y":[3145728.0],"yaxis":"y","type":"scatter"}]')

# %%
for s in j1:
  plt.plot(s['x'], s['y'], 'c--')
plt.plot(df1['time'], df1['F'], 'r')
# plt.plot(df2['time'], df2['F'], 'b')
plt.xlim(0.001,1e6)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Simulated Time [a.u.]')
plt.ylabel('Simulated Free Energy [a.u.]')
# Out:
# Text(0, 0.5, 'Simulated Free Energy [a.u.]')

# %%
for s in j2:
  plt.scatter(s['x'],[float(n) for n in s['y']], color = 'cyan')
plt.scatter([1360.425/9.433526e+03],[243e3], color = 'red')
plt.scatter([1360.425/9.433526e+03/64.1],[243e3], color = 'white')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t_{Wall}/t_{Sim}$')
plt.ylabel('Memory Usage [KB]')
# Out:
# Text(0, 0.5, 'Memory Usage [KB]')

# %%
Total runtime 26.7 m (to steady state)
(unconditionally stable timestep moose runs for 41m 47s to 604800s)

# %%
for s in j2:
  plt.scatter(s['x'],[float(n) for n in s['y']], color = 'cyan')
plt.scatter([1360.425/9.433526e+03],[243e3], color = 'blue')
plt.scatter([1360.425/9.433526e+03/64.111],[243e3], color = 'red')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t_{Wall}/t_{Sim}$')
plt.ylabel('Memory Usage [KB]')
# Out:
# Text(0, 0.5, 'Memory Usage [KB]')

# %%
plt.plot(df2['time'], df2['v'], 'b')
