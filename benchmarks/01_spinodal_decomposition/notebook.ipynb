# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# load PFHub results
with open('results.1a.1.json') as f:
  j1 = json.load(f)
j2 = json.loads('[{"hovertemplate":"Simulation Result=prismspf_1a<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"prismspf_1a","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"prismspf_1a","orientation":"h","showlegend":true,"x":[0.0708],"xaxis":"x","y":[30240],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=meumapps_bm1a<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"meumapps_bm1a","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"meumapps_bm1a","orientation":"h","showlegend":true,"x":[0.021],"xaxis":"x","y":["139200"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=fipy_1a_travis<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"fipy_1a_travis","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"fipy_1a_travis","orientation":"h","showlegend":true,"x":[28.35195590896475],"xaxis":"x","y":[470976],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=mmsp_1a_travis<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"mmsp_1a_travis","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"mmsp_1a_travis","orientation":"h","showlegend":true,"x":[5.844815497675869],"xaxis":"x","y":[33984],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=fenics_1a_ivan<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"fenics_1a_ivan","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"fenics_1a_ivan","orientation":"h","showlegend":true,"x":[0.00033447217661303306],"xaxis":"x","y":["3443352"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=memphis_1a<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"memphis_1a","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"memphis_1a","orientation":"h","showlegend":true,"x":[0.13864],"xaxis":"x","y":["444210"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=itg_moose_1a<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"itg_moose_1a","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"itg_moose_1a","orientation":"h","showlegend":true,"x":[0.0016527385710426042],"xaxis":"x","y":["1304498"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=mmsp_1a_raspi<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"mmsp_1a_raspi","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"mmsp_1a_raspi","orientation":"h","showlegend":true,"x":[70.03685917051266],"xaxis":"x","y":[8812],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_psu_1a_STA<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_psu_1a_STA","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"moose_psu_1a_STA","orientation":"h","showlegend":true,"x":[3.5863821138211383],"xaxis":"x","y":[104857600],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=mmsp_1a_wrksttn<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"mmsp_1a_wrksttn","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"mmsp_1a_wrksttn","orientation":"h","showlegend":true,"x":[2.94725321703326],"xaxis":"x","y":[28600],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_psu_1a_IA<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_psu_1a_IA","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"moose_psu_1a_IA","orientation":"h","showlegend":true,"x":[0.007531282179892009],"xaxis":"x","y":[104857600],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_fh_1a<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_fh_1a","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"moose_fh_1a","orientation":"h","showlegend":true,"x":[0.001244],"xaxis":"x","y":["1016432"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_1a_ia<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_1a_ia","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"moose_1a_ia","orientation":"h","showlegend":true,"x":[0.003975192278381062],"xaxis":"x","y":[815104],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=fipy_1a_10.5281/zenodo.7474506<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"fipy_1a_10.5281/zenodo.7474506","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"fipy_1a_10.5281/zenodo.7474506","orientation":"h","showlegend":true,"x":[28.35195590896475],"xaxis":"x","y":[470976],"yaxis":"y","type":"scatter"},{"hovertemplate":"Simulation Result=moose_1a_mpf<br><i>t</i><sub>Wall</sub> / <i>t</i><sub>Sim</sub> *=%{x}<br>Memory Usage [KB]=%{y}<extra></extra>","legendgroup":"moose_1a_mpf","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"moose_1a_mpf","orientation":"h","showlegend":true,"x":[0.0017746300000000001],"xaxis":"x","y":[1671430],"yaxis":"y","type":"scatter"}]')

# %%
df1 = pd.read_csv('1a_out.csv')
df2 = pd.read_csv('1a_solver_out.csv')
df3 = pd.read_csv('1a_secant_out.csv').dropna()[:-4]

# %%
for s in j1:
  plt.plot(s['x'], s['y'], 'c--')
plt.plot(df1['time'], df1['F'], 'r')
plt.plot(df2['time'], df2['F'], 'g')
plt.plot(df3['time'], df3['F'], 'b')
# plt.xlim(1,1e6)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Simulated Time [a.u.]')
plt.ylabel('Simulated Free Energy [a.u.]')
# Out:
# Text(0, 0.5, 'Simulated Free Energy [a.u.]')

# %%
for s in j2:
  plt.scatter(s['x'],[float(n) for n in s['y']], color = 'cyan')
plt.scatter([30.909/5.193482e+04],[227e3], color = 'red')
plt.scatter([53.196/4.457818e+04 ],[227e3], color = 'blue')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t_{Wall}/t_{Sim}$')
plt.ylabel('Memory Usage [KB]')
# Out:
# Text(0, 0.5, 'Memory Usage [KB]')

# %% [markdown]
# Total runtime 30.9 s (to steady state)
# (unconditionally stable timestep fenics runs for 6m28s)

# %%
plt.plot(df1['time'], df1['change'], 'r')
plt.xscale('log')
plt.yscale('log')
