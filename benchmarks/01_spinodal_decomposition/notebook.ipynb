# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df3 = pd.read_csv('1a_out.csv')

# %%
plt.plot(df1['time'], df1['F'])
plt.plot(df2['time'], df2['F'])
plt.plot(df3['time'], df3['F'])
plt.xscale('log')
